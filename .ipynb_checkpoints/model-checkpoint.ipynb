# %%
import numpy as np
import pandas as pd
import seaborn as sns
import time
from scipy.stats import chi2_contingency

import sklearn
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.feature_selection import SelectFromModel,SelectKBest, RFE, f_classif, mutual_info_classif
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_curve, auc
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn import svm

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Formatting

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf', 'png')
plt.rcParams['savefig.dpi'] = 75

plt.rcParams['figure.autolayout'] = False
plt.rcParams['figure.figsize'] = (7, 5)
plt.rcParams['axes.labelsize'] = 18
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['font.size'] = 16
plt.rcParams['lines.linewidth'] = 2.0
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 14

plt.rcParams['text.usetex'] = False
plt.rcParams['font.family'] = "sans-serif"
plt.rcParams['font.serif'] = "cm"
plt.rcParams['text.latex.preamble'] = "\\usepackage{subdepth} \\usepackage{type1cm}"

# %% [markdown]
# # Functions

# %%
class WeightedVotingClassifier():
    
    def __init__(self, class_score = t_score):
        self.class_score = class_score
                
        # For checking prediction input matches fit shape
        self.m = None
        self.n = None
        
        # Initialize empty before fitting        
        self.mu0 = None
        self.mu1 = None
        self.s0 = None
        self.s1 = None
        self.weights = None
        
        self.f1 = None
        
    def fit(self, X, y):        
        # For checking prediction input matches fit shape
        self.m, self.n = X.shape
        
        X0 = X[y == 0]
        X1 = X[y == 1]
    
        self.mu0 = np.mean(X0, axis = 0)
        self.mu1 = np.mean(X1, axis = 0)
        self.s0 = np.std(X0, axis = 0)
        self.s1 = np.std(X1, axis = 0)
        self.weights = self.class_score(X, y)
        
    def predict(self, X):
        m, n = X.shape
        assert n == self.n, "Input data does not match fit dimensions."
        
        votes = np.zeros((m, 2))
        
        for i, xg in enumerate(X):
            for j, k in enumerate(xg):
                d0 = np.abs((k - self.mu0[j])/self.s0[j])
                d1 = np.abs((k - self.mu1[j])/self.s1[j])
                if d0 < d1:
                    votes[i, 0] += self.weights[j]*d0
                else:
                    votes[i, 1] += self.weights[j]*d1
                    
        self.f1 = votes[:,1]/np.sum(votes, axis = 1)
        preds = np.argmax(votes, axis = 1)
        
        return preds
    
    def decision_function(self, X):
        self.predict(X) # Update 1 fraction weights
        return self.f1
    
    def get_params(self, deep = False):
        return {'class_score': self.class_score}

# %%
def t_score(X, y):
    X0 = X[y == 0]
    X1 = X[y == 1]
    
    mu0 = np.mean(X0, axis = 0)
    mu1 = np.mean(X1, axis = 0)
    
    s0 = np.std(X0, axis = 0)
    s1 = np.std(X1, axis = 0)
    
    return np.abs(mu0 - mu1)/(s0 + s1)

def z_score(X):
    mu = np.mean(X, axis = 0)
    s = np.std(X, axis = 0)
    
    return (X - mu)/s

# %%
def calc_roc_auc(model, X_test, y_test):
    
    if hasattr(model, "decision_function"):
        y_score = model.decision_function(X_test)
    elif hasattr(model, "predict_proba"):
        y_score = model.predict_proba(X_test)[:,1]
    else:
        print("No valid scoring metric for model -- breaking.")
        return
    
    fpr, tpr, thresholds = roc_curve(y_test, y_score)
    roc_auc = auc(fpr, tpr)
    
    return (fpr, tpr, roc_auc)



def plot_roc_curve(fpr, tpr, roc_auc):    
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=1, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('1 - Specificity')
    plt.ylabel('Sensitivity')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# # Data Import

# %%
b_df = pd.read_csv("data/matrix_bronchial.csv", index_col = 0)
n_df = pd.read_csv("data/matrix_nasal.csv", index_col = 0)

# %%
train_df, test_df = sklearn.model_selection.train_test_split(n_df, test_size = 0.3, random_state = 12345)
(train_df.shape[0], test_df.shape[0])
# Out:
# (340, 147)

# %%
train_df.head()
# Out:
#             cancer        age  gender  smoker  smoking_quit  mass_size  \
# geoid
# GSM2137480       0  53.871233       0       0            -1         -1
# GSM2137397       0  51.980822       0       1             1         -1
# GSM2137109       0  49.000000       1       1             1          1
# GSM2137580       1  60.421918       1       0             1          1
# GSM2137421       1  73.046575       0       1             1          1
#
#              7892501   7892502   7892503   7892504    ...      8180408  \
# geoid                                                 ...
# GSM2137480  1.626633  3.977878  2.986823  8.730259    ...     8.069860
# GSM2137397  1.270296  3.239412  4.719865  9.105564    ...     7.268308
# GSM2137109  1.931912  3.657101  4.390043  8.623355    ...     7.820397
# GSM2137580  3.408263  4.290578  2.439563  8.792918    ...     8.458438
# GSM2137421  1.715925  3.440971  2.885006  9.274841    ...     6.992559
#
#              8180409   8180410   8180411   8180413    8180414   8180415  \
# geoid
# GSM2137480  8.904318  8.903292  5.905798  6.802455   9.828038  5.857784
# GSM2137397  8.648345  8.840798  6.176627  7.136958  10.028481  5.600210
# GSM2137109  9.069256  9.384279  5.380734  6.846073   9.381491  5.983618
# GSM2137580  9.349588  9.064940  5.261172  6.367427   9.032344  6.631996
# GSM2137421  8.473722  8.647412  5.560813  7.134567   9.606771  5.770544
#
#              8180416   8180417   8180418
# geoid
# GSM2137480  4.256195  7.502483  8.812916
# GSM2137397  4.913954  7.699453  8.852938
# GSM2137109  4.185220  7.542234  8.736329
# GSM2137580  4.799999  7.541905  7.737475
# GSM2137421  4.806015  7.318142  8.378846
#
# [5 rows x 32327 columns]

# %% [markdown]
# # Clinical Data Classifier

# %%
# Pull Data
X_train = train_df.iloc[:,1:].values
y_train = train_df.iloc[:,0].values
X_test = test_df.iloc[:,1:].values
y_test = test_df.iloc[:,0].values

X_train = StandardScaler().fit_transform(X_train)
X_test = StandardScaler().fit_transform(X_test)

# %%
X_train_clinical = X_train[:,0:5]
X_test_clinical = X_test[:,0:5]

# %% [markdown]
# ## PCA

# %%
k = 2

pca = PCA(n_components = k)
pca_fit = pca.fit_transform(X_train_clinical)

v1, v2 = pca.explained_variance_ratio_

print("Explained variance: [{:.3f}, {:.3f}]".format(v1, v2))
# Out:
# Explained variance: [0.361, 0.218]

# %%
pca_df = pd.DataFrame(data = pca_fit, columns = ['pc1', 'pc2'], index = train_df.index)
pca_df = pd.concat([train_df["cancer"], pca_df], axis = 1)

# %%
fig = plt.figure(figsize = (8,6))


ax = fig.add_subplot(1,1,1) 
ax.set_xlabel("PC-1 ({:.1f}%)".format(100*v1), fontsize = 15)
ax.set_ylabel("PC-2 ({:.1f}%)".format(100*v2), fontsize = 15)

colors = ['r', 'b']
targets = [0, 1]

for target, color in zip(targets,colors):
    idx = pca_df['cancer'] == target
    ax.scatter(pca_df.loc[idx, 'pc1'], pca_df.loc[idx, 'pc2'], c = color, s = 40)
ax.legend(["No Cancer", "Cancer"])
ax.grid()

# %% [markdown]
# ## Model Testing

# %% [markdown]
# ### Weighted Voting

# %%
wv_clinical = WeightedVotingClassifier()
wv_clinical.fit(X_train_clinical, y_train)

# %%
scores = cross_val_score(wv_clinical, X_train_clinical, y_train, cv = 10, scoring = "accuracy")
accuracy = np.mean(scores)

print("Mean CV Accuracy = {}".format(accuracy))
# Out:
# Mean CV Accuracy = 0.638235294117647

# %%
fpr, tpr, roc_auc = calc_roc_auc(wv_clinical, X_test_clinical, y_test)

plot_roc_curve(fpr, tpr, roc_auc)

# %% [markdown]
# ### Logistic Regression

# %%
lr_clinical = LogisticRegression(solver = "newton-cg")
lr_clinical.fit(X_train_clinical, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='newton-cg',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
scores = cross_val_score(lr_clinical, X_train_clinical, y_train, cv = 10, scoring = "accuracy")
accuracy = np.mean(scores)

print("Mean CV Accuracy = {}".format(accuracy))
# Out:
# Mean CV Accuracy = 0.64349376114082

# %%
fpr, tpr, roc_auc = calc_roc_auc(lr_clinical, X_test_clinical, y_test)

plot_roc_curve(fpr, tpr, roc_auc)

# %% [markdown]
# ### SVM

# %%
svr_clinical = svm.SVC(C = 2.5, gamma = "auto", kernel = "rbf")
svr_clinical.fit(X_train_clinical, y_train)
# Out:
# SVC(C=2.5, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
scores = cross_val_score(svr_clinical, X_train_clinical, y_train, cv = 10, scoring = "accuracy")
accuracy = np.mean(scores)

print("Mean CV Accuracy = {}".format(accuracy))
# Out:
# Mean CV Accuracy = 0.7117850776674306

# %%
fpr, tpr, roc_auc = calc_roc_auc(svr_clinical, X_test_clinical, y_test)

plot_roc_curve(fpr, tpr, roc_auc)

# %% [markdown]
# ### Random Forest

# %%
rfc_clinical = RandomForestClassifier(random_state = 12345, n_estimators = 500)
rfc_clinical.fit(X_train_clinical, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=None,
#             oob_score=False, random_state=12345, verbose=0,
#             warm_start=False)

# %%
scores = cross_val_score(rfc_clinical, X_train_clinical, y_train, cv = 10, scoring = "accuracy")
accuracy = np.mean(scores)

print("Mean CV Accuracy = {}".format(accuracy))
# Out:
# Mean CV Accuracy = 0.6495747389865038

# %%
fpr, tpr, roc_auc = calc_roc_auc(rfc_clinical, X_test_clinical, y_test)

plot_roc_curve(fpr, tpr, roc_auc)

# %% [markdown]
# # Feature and Model Selection

# %%
# Pull Data
X_train = train_df.iloc[:,1:].values
y_train = train_df.iloc[:,0].values
X_test = test_df.iloc[:,1:].values
y_test = test_df.iloc[:,0].values

X_train = StandardScaler().fit_transform(X_train)
X_test = StandardScaler().fit_transform(X_test)

# %%
X_train_clinical = X_train[:,0:5]
X_test_clinical = X_test[:,0:5]

X_train_rna = X_train[:,5:]
X_test_rna = X_test[:,5:]

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ### T-Score

# %%
max_nf = 100
max_accuracy = 0
max_k = 0

k_vals = np.arange(5, max_nf + 1, 5)

cv_accuracy = np.zeros(k_vals.shape[0])
cv_std = np.zeros(k_vals.shape[0])
roc_auc = np.zeros(k_vals.shape[0])

for i, k in enumerate(k_vals):
    
    selector = SelectKBest(t_score, k = k)
    selector.fit(X_train_rna, y_train)
    
    X_train_sel = selector.transform(X_train_rna)
    X_test_sel = selector.transform(X_test_rna)
      
    lr = LogisticRegression(solver = "newton-cg")
    lr.fit(X_train_sel, y_train)
    scores = cross_val_score(lr, X_train_sel, y_train, cv = 10, scoring = "accuracy")
    cva = np.mean(scores)
    cvs = np.std(scores)
    
    if cva > max_accuracy:
        max_accuracy = cva
        max_k = k
        print("k = {}, Mean CV Accuracy = {}".format(max_k, max_accuracy))
        
    cv_accuracy[i] = cva
    cv_std[i] = cvs
    
    _, _, area = calc_roc_auc(lr, X_test_sel, y_test)
    roc_auc[i] = area
# Out:
# k = 5, Mean CV Accuracy = 0.6527731092436976

# %%
fig, ax = plt.subplots(1, 3, figsize=(14,4)) 
plt.subplots_adjust(wspace = 0.3)

ax1, ax2, ax3 = ax

ax1.plot(k_vals, cv_accuracy)
ax1.set_xlabel("k")
ax1.set_ylabel("Mean CV Accuracy")

ax2.plot(k_vals, cv_std)
ax2.set_xlabel("k")
ax2.set_ylabel("CV Standard Deviation")

ax3.plot(k_vals, roc_auc)
ax3.set_xlabel("k")
ax3.set_ylabel("AUC")

plt.show()

# %% [markdown]
# ### F-Value

# %%
max_nf = 100
max_accuracy = 0
max_k = 0

k_vals = np.arange(5, max_nf + 1, 5)

cv_accuracy = np.zeros(k_vals.shape[0])
cv_std = np.zeros(k_vals.shape[0])
roc_auc = np.zeros(k_vals.shape[0])

for i, k in enumerate(k_vals):
    
    selector = SelectKBest(f_classif, k = k)
    selector.fit(X_train_rna, y_train)
    
    X_train_sel = selector.transform(X_train_rna)
    X_test_sel = selector.transform(X_test_rna)
      
    lr = LogisticRegression(solver = "newton-cg")
    lr.fit(X_train_sel, y_train)
    scores = cross_val_score(lr, X_train_sel, y_train, cv = 10, scoring = "accuracy")
    cva = np.mean(scores)
    cvs = np.std(scores)
    
    if cva > max_accuracy:
        max_accuracy = cva
        max_k = k
        print("k = {}, Mean CV Accuracy = {}".format(max_k, max_accuracy))
        
    cv_accuracy[i] = cva
    cv_std[i] = cvs
    
    _, _, area = calc_roc_auc(lr, X_test_sel, y_test)
    roc_auc[i] = area
# Out:
# k = 5, Mean CV Accuracy = 0.6410822510822511
# k = 15, Mean CV Accuracy = 0.6412503183091418
# k = 25, Mean CV Accuracy = 0.6493022663610899
# k = 35, Mean CV Accuracy = 0.655704099821747

# %%
fig, ax = plt.subplots(1, 3, figsize=(14,4)) 
plt.subplots_adjust(wspace = 0.3)

ax1, ax2, ax3 = ax

ax1.plot(k_vals, cv_accuracy)
ax1.set_xlabel("k")
ax1.set_ylabel("Mean CV Accuracy")

ax2.plot(k_vals, cv_std)
ax2.set_xlabel("k")
ax2.set_ylabel("CV Standard Deviation")

ax3.plot(k_vals, roc_auc)
ax3.set_xlabel("k")
ax3.set_ylabel("AUC")

plt.show()

# %% [markdown]
# ### Tree-Based

# %%
max_nf = 100
max_accuracy = 0
max_k = 0

k_vals = np.arange(5, max_nf + 1, 5)

cv_accuracy = np.zeros(k_vals.shape[0])
cv_std = np.zeros(k_vals.shape[0])
roc_auc = np.zeros(k_vals.shape[0])

for i, k in enumerate(k_vals):
    
    model = ExtraTreesClassifier(n_estimators = 100, random_state = 12345)
    model.fit(X_train_rna, y_train)
    selector = SelectFromModel(model, prefit = True, max_features = k)

    X_train_sel = selector.transform(X_train_rna)
    X_test_sel = selector.transform(X_test_rna)

    lr = LogisticRegression(solver = "newton-cg")
    lr.fit(X_train_sel, y_train)
    scores = cross_val_score(lr, X_train_sel, y_train, cv = 10, scoring = "accuracy")
    cva = np.mean(scores)
    cvs = np.std(scores)
    
    if cva > max_accuracy:
        max_accuracy = cva
        max_k = k
        print("k = {}, Mean CV Accuracy = {}".format(max_k, max_accuracy))
        
    cv_accuracy[i] = cva
    cv_std[i] = cvs
    
    _, _, area = calc_roc_auc(lr, X_test_sel, y_test)
    roc_auc[i] = area
# Out:
# k = 5, Mean CV Accuracy = 0.6674789915966388
# k = 10, Mean CV Accuracy = 0.6742220524573466
# k = 30, Mean CV Accuracy = 0.6854672778202191
# k = 35, Mean CV Accuracy = 0.6903259485612426

# %%
fig, ax = plt.subplots(1, 3, figsize=(14,4)) 
plt.subplots_adjust(wspace = 0.3)

ax1, ax2, ax3 = ax

ax1.plot(k_vals, cv_accuracy)
ax1.set_xlabel("k")
ax1.set_ylabel("Mean CV Accuracy")

ax2.plot(k_vals, cv_std)
ax2.set_xlabel("k")
ax2.set_ylabel("CV Standard Deviation")

ax3.plot(k_vals, roc_auc)
ax3.set_xlabel("k")
ax3.set_ylabel("AUC")

plt.show()

# %% [markdown]
# ## SVM

# %% [markdown]
# ### T-Score

# %%
max_nf = 100
max_accuracy = 0
max_k = 0

k_vals = np.arange(5, max_nf + 1, 5)

cv_accuracy = np.zeros(k_vals.shape[0])
cv_std = np.zeros(k_vals.shape[0])
roc_auc = np.zeros(k_vals.shape[0])

for i, k in enumerate(k_vals):
    
    selector = SelectKBest(t_score, k = k)
    selector.fit(X_train_rna, y_train)
    
    X_train_sel = selector.transform(X_train_rna)
    X_test_sel = selector.transform(X_test_rna)
      
    svr = svm.SVC(C = 3, gamma = "auto", kernel = "rbf")
    svr.fit(X_train_sel, y_train)
    scores = cross_val_score(svr, X_train_sel, y_train, cv = 10, scoring = "accuracy")
    cva = np.mean(scores)
    cvs = np.std(scores)
    
    if cva > max_accuracy:
        max_accuracy = cva
        max_k = k
        print("k = {}, Mean CV Accuracy = {}".format(max_k, max_accuracy))
        
    cv_accuracy[i] = cva
    cv_std[i] = cvs
    
    _, _, area = calc_roc_auc(svr, X_test_sel, y_test)
    roc_auc[i] = area
# Out:
# k = 5, Mean CV Accuracy = 0.6498268398268399
# k = 15, Mean CV Accuracy = 0.6769111280875988

# %%
fig, ax = plt.subplots(1, 3, figsize=(14,4)) 
plt.subplots_adjust(wspace = 0.3)

ax1, ax2, ax3 = ax

ax1.plot(k_vals, cv_accuracy)
ax1.set_xlabel("k")
ax1.set_ylabel("Mean CV Accuracy")

ax2.plot(k_vals, cv_std)
ax2.set_xlabel("k")
ax2.set_ylabel("CV Standard Deviation")

ax3.plot(k_vals, roc_auc)
ax3.set_xlabel("k")
ax3.set_ylabel("AUC")

plt.show()

# %% [markdown]
# ### F-Value

# %%
max_nf = 100
max_accuracy = 0
max_k = 0

k_vals = np.arange(5, max_nf + 1, 5)

cv_accuracy = np.zeros(k_vals.shape[0])
cv_std = np.zeros(k_vals.shape[0])
roc_auc = np.zeros(k_vals.shape[0])

for i, k in enumerate(k_vals):
    
    selector = SelectKBest(f_classif, k = k)
    selector.fit(X_train_rna, y_train)
    
    X_train_sel = selector.transform(X_train_rna)
    X_test_sel = selector.transform(X_test_rna)
      
    svr = svm.SVC(C = 3, gamma = "auto", kernel = "rbf")
    svr.fit(X_train_sel, y_train)
    scores = cross_val_score(svr, X_train_sel, y_train, cv = 10, scoring = "accuracy")
    cva = np.mean(scores)
    cvs = np.std(scores)
    
    if cva > max_accuracy:
        max_accuracy = cva
        max_k = k
        print("k = {}, Mean CV Accuracy = {}".format(max_k, max_accuracy))
        
    cv_accuracy[i] = cva
    cv_std[i] = cvs
    
    _, _, area = calc_roc_auc(svr, X_test_sel, y_test)
    roc_auc[i] = area
# Out:
# k = 5, Mean CV Accuracy = 0.6564858670741025
# k = 15, Mean CV Accuracy = 0.6769111280875988

# %%
fig, ax = plt.subplots(1, 3, figsize=(14,4)) 
plt.subplots_adjust(wspace = 0.3)

ax1, ax2, ax3 = ax

ax1.plot(k_vals, cv_accuracy)
ax1.set_xlabel("k")
ax1.set_ylabel("Mean CV Accuracy")

ax2.plot(k_vals, cv_std)
ax2.set_xlabel("k")
ax2.set_ylabel("CV Standard Deviation")

ax3.plot(k_vals, roc_auc)
ax3.set_xlabel("k")
ax3.set_ylabel("AUC")

plt.show()

# %% [markdown]
# ### Tree Based

# %%
max_nf = 100
max_accuracy = 0
max_k = 0

k_vals = np.arange(5, max_nf + 1, 5)

cv_accuracy = np.zeros(k_vals.shape[0])
cv_std = np.zeros(k_vals.shape[0])
roc_auc = np.zeros(k_vals.shape[0])

for i, k in enumerate(k_vals):
    
    model = ExtraTreesClassifier(n_estimators = 100, random_state = 12345)
    model.fit(X_train_rna, y_train)
    selector = SelectFromModel(model, prefit = True, max_features = k)

    X_train_sel = selector.transform(X_train_rna)
    X_test_sel = selector.transform(X_test_rna)

    svr = svm.SVC(C = 3, gamma = "auto", kernel = "rbf")
    svr.fit(X_train_sel, y_train)
    scores = cross_val_score(svr, X_train_sel, y_train, cv = 10, scoring = "accuracy")
    cva = np.mean(scores)
    cvs = np.std(scores)
    
    if cva > max_accuracy:
        max_accuracy = cva
        max_k = k
        print("k = {}, Mean CV Accuracy = {}".format(max_k, max_accuracy))
        
    cv_accuracy[i] = cva
    cv_std[i] = cvs
    
    _, _, area = calc_roc_auc(svr, X_test_sel, y_test)
    roc_auc[i] = area
# Out:
# k = 5, Mean CV Accuracy = 0.661502419149478
# k = 10, Mean CV Accuracy = 0.6622841864018335
# k = 40, Mean CV Accuracy = 0.6675477463712759
# k = 45, Mean CV Accuracy = 0.6788871912401325
# k = 55, Mean CV Accuracy = 0.6820066208301504
# k = 65, Mean CV Accuracy = 0.6908352431881845
# k = 75, Mean CV Accuracy = 0.6935981665393431

# %%
fig, ax = plt.subplots(1, 3, figsize=(14,4)) 
plt.subplots_adjust(wspace = 0.3)

ax1, ax2, ax3 = ax

ax1.plot(k_vals, cv_accuracy)
ax1.set_xlabel("k")
ax1.set_ylabel("Mean CV Accuracy")

ax2.plot(k_vals, cv_std)
ax2.set_xlabel("k")
ax2.set_ylabel("CV Standard Deviation")

ax3.plot(k_vals, roc_auc)
ax3.set_xlabel("k")
ax3.set_ylabel("AUC")

plt.show()

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### T-Score

# %%
max_nf = 100
max_accuracy = 0
max_k = 0

k_vals = np.arange(5, max_nf + 1, 5)

cv_accuracy = np.zeros(k_vals.shape[0])
cv_std = np.zeros(k_vals.shape[0])
roc_auc = np.zeros(k_vals.shape[0])

for i, k in enumerate(k_vals):
    
    selector = SelectKBest(t_score, k = k)
    selector.fit(X_train_rna, y_train)
    
    X_train_sel = selector.transform(X_train_rna)
    X_test_sel = selector.transform(X_test_rna)
      
    rfc = RandomForestClassifier(n_estimators = 100, random_state = 12345)
    rfc.fit(X_train_sel, y_train)
    scores = cross_val_score(rfc, X_train_sel, y_train, cv = 10, scoring = "accuracy")
    cva = np.mean(scores)
    cvs = np.std(scores)
    
    if cva > max_accuracy:
        max_accuracy = cva
        max_k = k
        print("k = {}, Mean CV Accuracy = {}".format(max_k, max_accuracy))
        
    cv_accuracy[i] = cva
    cv_std[i] = cvs
    
    _, _, area = calc_roc_auc(rfc, X_test_sel, y_test)
    roc_auc[i] = area
# Out:
# k = 5, Mean CV Accuracy = 0.6265444359562007
# k = 15, Mean CV Accuracy = 0.6648790425261015

# %%
fig, ax = plt.subplots(1, 3, figsize=(14,4)) 
plt.subplots_adjust(wspace = 0.3)

ax1, ax2, ax3 = ax

ax1.plot(k_vals, cv_accuracy)
ax1.set_xlabel("k")
ax1.set_ylabel("Mean CV Accuracy")

ax2.plot(k_vals, cv_std)
ax2.set_xlabel("k")
ax2.set_ylabel("CV Standard Deviation")

ax3.plot(k_vals, roc_auc)
ax3.set_xlabel("k")
ax3.set_ylabel("AUC")

plt.show()

# %% [markdown]
# ### F-Value

# %%
max_nf = 100
max_accuracy = 0
max_k = 0

k_vals = np.arange(5, max_nf + 1, 5)

cv_accuracy = np.zeros(k_vals.shape[0])
cv_std = np.zeros(k_vals.shape[0])
roc_auc = np.zeros(k_vals.shape[0])

for i, k in enumerate(k_vals):
    
    selector = SelectKBest(f_classif, k = k)
    selector.fit(X_train_rna, y_train)
    
    X_train_sel = selector.transform(X_train_rna)
    X_test_sel = selector.transform(X_test_rna)
      
    rfc = RandomForestClassifier(n_estimators = 100, random_state = 12345)
    rfc.fit(X_train_sel, y_train)
    scores = cross_val_score(rfc, X_train_sel, y_train, cv = 10, scoring = "accuracy")
    cva = np.mean(scores)
    cvs = np.std(scores)
    
    if cva > max_accuracy:
        max_accuracy = cva
        max_k = k
        print("k = {}, Mean CV Accuracy = {}".format(max_k, max_accuracy))
        
    cv_accuracy[i] = cva
    cv_std[i] = cvs
    
    _, _, area = calc_roc_auc(rfc, X_test_sel, y_test)
    roc_auc[i] = area
# Out:
# k = 5, Mean CV Accuracy = 0.6241125541125542
# k = 10, Mean CV Accuracy = 0.6536287242169596
# k = 15, Mean CV Accuracy = 0.6648790425261015

# %%
fig, ax = plt.subplots(1, 3, figsize=(14,4)) 
plt.subplots_adjust(wspace = 0.3)

ax1, ax2, ax3 = ax

ax1.plot(k_vals, cv_accuracy)
ax1.set_xlabel("k")
ax1.set_ylabel("Mean CV Accuracy")

ax2.plot(k_vals, cv_std)
ax2.set_xlabel("k")
ax2.set_ylabel("CV Standard Deviation")

ax3.plot(k_vals, roc_auc)
ax3.set_xlabel("k")
ax3.set_ylabel("AUC")

plt.show()

# %% [markdown]
# ### Tree Based

# %%
max_nf = 100
max_accuracy = 0
max_k = 0

k_vals = np.arange(5, max_nf + 1, 5)

cv_accuracy = np.zeros(k_vals.shape[0])
cv_std = np.zeros(k_vals.shape[0])
roc_auc = np.zeros(k_vals.shape[0])

for i, k in enumerate(k_vals):
    
    model = ExtraTreesClassifier(n_estimators = 100, random_state = 12345)
    model.fit(X_train_rna, y_train)
    selector = SelectFromModel(model, prefit = True, max_features = k)

    X_train_sel = selector.transform(X_train_rna)
    X_test_sel = selector.transform(X_test_rna)

    rfc = RandomForestClassifier(n_estimators = 100, random_state = 12345)
    rfc.fit(X_train_sel, y_train)
    scores = cross_val_score(rfc, X_train_sel, y_train, cv = 10, scoring = "accuracy")
    cva = np.mean(scores)
    cvs = np.std(scores)
    
    if cva > max_accuracy:
        max_accuracy = cva
        max_k = k
        print("k = {}, Mean CV Accuracy = {}".format(max_k, max_accuracy))
        
    cv_accuracy[i] = cva
    cv_std[i] = cvs
    
    _, _, area = calc_roc_auc(rfc, X_test_sel, y_test)
    roc_auc[i] = area
# Out:
# k = 5, Mean CV Accuracy = 0.6588184364654953
# k = 10, Mean CV Accuracy = 0.6800203717850777
# k = 45, Mean CV Accuracy = 0.6884186401833461

# %%
fig, ax = plt.subplots(1, 3, figsize=(14,4)) 
plt.subplots_adjust(wspace = 0.3)

ax1, ax2, ax3 = ax

ax1.plot(k_vals, cv_accuracy)
ax1.set_xlabel("k")
ax1.set_ylabel("Mean CV Accuracy")

ax2.plot(k_vals, cv_std)
ax2.set_xlabel("k")
ax2.set_ylabel("CV Standard Deviation")

ax3.plot(k_vals, roc_auc)
ax3.set_xlabel("k")
ax3.set_ylabel("AUC")

plt.show()

# %% [markdown]
# # Model Tuning

# %% [markdown]
# In this section, we optimize hyperparameters for both an SVM and RF classifier, using the optimal feature subset determined from the above analysis.

# %%
# Pull Data
X_train = train_df.iloc[:,1:].values
y_train = train_df.iloc[:,0].values
X_test = test_df.iloc[:,1:].values
y_test = test_df.iloc[:,0].values

X_train = StandardScaler().fit_transform(X_train)
X_test = StandardScaler().fit_transform(X_test)

# %%
X_train_clinical = X_train[:,0:5]
X_test_clinical = X_test[:,0:5]

X_train_rna = X_train[:,5:]
X_test_rna = X_test[:,5:]

# %%
model = ExtraTreesClassifier(n_estimators = 100, random_state = 12345)
model.fit(X_train_rna, y_train)
selector = SelectFromModel(model, prefit = True, max_features = 75)

X_train_sel = selector.transform(X_train_rna)
X_test_sel = selector.transform(X_test_rna)

# %%
X_train_combo = np.concatenate((X_train_clinical, X_train_sel), 1)
X_test_combo = np.concatenate((X_test_clinical, X_test_sel), 1)

# %% [markdown]
# ## SVM

# %%
svr = svm.SVC(C = 3, gamma = "auto", kernel = "rbf")
svr.fit(X_train_combo, y_train)
# Out:
# SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
scores = cross_val_score(svr, X_train_combo, y_train, cv = 10, scoring = "accuracy")

# %%
np.mean(scores)
# Out:
# 0.7317748917748917

# %%
fpr, tpr, roc_auc = calc_roc_auc(svr, X_test_combo, y_test)

plot_roc_curve(fpr, tpr, roc_auc)

# %% [markdown]
# ## Random Forest

# %%
rfc = RandomForestClassifier(n_estimators = 100, random_state = 12345)
rfc.fit(X_train_combo, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=12345, verbose=0,
#             warm_start=False)

# %%
scores = cross_val_score(rfc, X_train_combo, y_train, cv = 10, scoring = "accuracy")

# %%
fpr, tpr, roc_auc = calc_roc_auc(rfc, X_test_combo, y_test)

plot_roc_curve(fpr, tpr, roc_auc)
